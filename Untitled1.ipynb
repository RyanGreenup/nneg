-- %%
-- Comments are fun

--[[
 Multi line comment 


sdfasdf


--]]

-- %%
print("foo")
-- Out:
-- foo

-- %%
function blah()
    print(9*7)
end

blah()
-- Out:
-- 63

-- %%
-- define the function
function f(x) return math.sin(x) * x^2 end

-- %%
-- create a plot of f(x) for x going from 0 to 25
p = graph.plot("y = sin(x) * x^2")
line = graph.fxline(f, 0, 25)
p:addline(line, "red")
p:show()
-- Out:
-- (ilua):2: attempt to index a nil value (global 'graph')
-- stack traceback:
-- 	(ilua):2: in main chunk
-- 	[C]: in function 'xpcall'
-- 	/usr/lib/python3.10/site-packages/ilua/interp.lua:65: in local 'handle_execute'
-- 	/usr/lib/python3.10/site-packages/ilua/interp.lua:162: in main chunk
-- 	[C]: in ?

-- %%
local math = require("sci.math").generic
local diff = require("sci.diff")
-- Out:
-- (ilua):1: module 'sci.math' not found:
-- 	no field package.preload['sci.math']
-- 	no file '/usr/share/lua/5.4/sci/math.lua'
-- 	no file '/usr/share/lua/5.4/sci/math/init.lua'
-- 	no file '/usr/lib/lua/5.4/sci/math.lua'
-- 	no file '/usr/lib/lua/5.4/sci/math/init.lua'
-- 	no file './sci/math.lua'
-- 	no file './sci/math/init.lua'
-- 	no file '/usr/lib/python3.10/site-packages/ilua/sci/math.lua'
-- 	no file '/usr/lib/lua/5.4/sci/math.so'
-- 	no file '/usr/lib/lua/5.4/loadall.so'
-- 	no file './sci/math.so'
-- 	no file '/usr/lib/lua/5.4/sci.so'
-- 	no file '/usr/lib/lua/5.4/loadall.so'
-- 	no file './sci.so'
-- stack traceback:
-- 	[C]: in function 'require'
-- 	(ilua):1: in main chunk
-- 	[C]: in function 'xpcall'
-- 	/usr/lib/python3.10/site-packages/ilua/interp.lua:65: in local 'handle_execute'
-- 	/usr/lib/python3.10/site-packages/ilua/interp.lua:162: in main chunk
-- 	[C]: in ?
