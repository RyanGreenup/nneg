# %%
x = var('x')

# %%
simplify(sqrt(x*x))
# Out:
# sqrt(x^2)

# %%
integrate(exp(sin(x)^2+cos(x)), x)
# Out:
# // Giac share root-directory:/usr/share/giac/
# // Giac share root-directory:/usr/share/giac/
# Added 0 synonyms
# integrate(e^sin(x), x)
